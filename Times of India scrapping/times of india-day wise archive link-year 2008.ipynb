# %%
import pandas as pd

# %%
archive_link_2008 = []

# %%
for i in range(0,3200):
    archive_link_2008.append('https://timesofindia.indiatimes.com/2008/1/1/archivelist/year-2008,month-1,starttime-'+str(39948+i)+'.cms')

# %%
archive_link_2008
# Out:
# ['https://timesofindia.indiatimes.com/2008/1/1/archivelist/year-2008,month-1,starttime-39948.cms',
#  'https://timesofindia.indiatimes.com/2008/1/1/archivelist/year-2008,month-1,starttime-39949.cms',
#  'https://timesofindia.indiatimes.com/2008/1/1/archivelist/year-2008,month-1,starttime-39950.cms',
#  'https://timesofindia.indiatimes.com/2008/1/1/archivelist/year-2008,month-1,starttime-39951.cms',
#  'https://timesofindia.indiatimes.com/2008/1/1/archivelist/year-2008,month-1,starttime-39952.cms',
#  'https://timesofindia.indiatimes.com/2008/1/1/archivelist/year-2008,month-1,starttime-39953.cms',
#  'https://timesofindia.indiatimes.com/2008/1/1/archivelist/year-2008,month-1,starttime-39954.cms',
#  'https://timesofindia.indiatimes.com/2008/1/1/archivelist/year-2008,month-1,starttime-39955.cms',
#  'https://timesofindia.indiatimes.com/2008/1/1/archivelist/year-2008,month-1,starttime-39956.cms',
# ...

# %%
archive_link_2008[3199]
# Out:
# 'https://timesofindia.indiatimes.com/2008/1/1/archivelist/year-2008,month-1,starttime-43147.cms'

# %%
df = pd.DataFrame(archive_link_2008)

# %%
df.to_csv("C:/Users/HP/Documents/Better India Project/day_wise_links_times_of_india.csv")
